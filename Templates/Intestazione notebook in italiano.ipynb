# %% [markdown]
# Questo notebook é stato scritto per finalità di formazione e rilasciato in base ad una licenza Creative Commons CC BY License.
#
# https://creativecommons.org/licenses/by/4.0/
#
# E' stato creato per le presentazioni in aula in Università Cattolica del Sacro Cuore di Milano, da Deborah Grbac e Valentina Schiariti, riutilizzando materiali educativi ad accesso aperto presenti nel repository Constellate creato e depositato in Git-Hub dai JSTOR Labs (ITHAKA) e materiali educativi ad accesso aperto del Text Analysis Pedagogy Institute, organizzato dai JSTOR Labs.
#
# Per domande/commenti/miglioramenti: scrivere a deborah.grbac@unicatt.it, valentina.schiariti-collaboratore@unicatt.it.
