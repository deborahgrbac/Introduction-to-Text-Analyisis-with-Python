# %% [markdown]
# This notebook has been written for educational purpose and has been released under a Creative Commons CC BY License.
#
# https://creativecommons.org/licenses/by/4.0/
#
# Created by Deborah Grbac and Valentina Schiariti, for the "Introduction to Text Analysis" course at Università Cattolica del Sacro Cuore di Milano, reusing materials from Constellate repository created by JSTOR Labs (ITHAKA) and materials from the Text Analysis Pedagogy Institute organized by JSTOR Labs.
#
# For questions/comments/improvements: write at deborah.grbac@unicatt.it, valentina.schiariti-collaboratore@unicatt.it.
