# %% [markdown]
# # Try it out!
#
# Here's [the first 50 pages of an edition of Moby Dick from 1922](../All-sample-files/moby_dick.pdf). Can you OCR all the pages and then generate a list of errors based on dictionary analysis? How about replacing some of the text with errors?
